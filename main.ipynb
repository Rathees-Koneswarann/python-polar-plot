# %% [markdown]
# ## Plot simple polar curves in python

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %% [markdown]
# Plot a point

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
  
# plot
plt.polar(np.pi, 2, 'g.')

# display the Polar plot
plt.show()

# %% [markdown]
# Plot a circle

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
  
# setting the radius
r = 2
  
# creating an array containing the
# radian values
rads = np.arange(0, (2 * np.pi), 0.01)
  
# plotting the circle
for rad in rads:
    plt.polar(rad, r, 'g.')
  
# display the Polar plot
plt.show()

# %% [markdown]
# Plot sine wave

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
    
# creating an array containing the
# radian values
x = np.arange(0, (2 * np.pi), 0.01)
y = np.sin(x)  

# plotting the circle
plt.plot(x, y)
  
# display the Polar plot
plt.show()

# %% [markdown]
# Plot sin wave in different range

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
    
# creating an array containing the
# radian values
x = np.arange(0, np.pi, 0.01)
y = np.sin(x)  

# plotting the circle
plt.plot(x, y)
  
# display the Polar plot
plt.show()

# %% [markdown]
# Plot absolute value of sin

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
    
# creating an array containing the
# radian values
x = np.arange(0, (2 * np.pi), 0.01)
y = np.abs(np.sin(x))  

# plotting the circle
plt.plot(x, y)
  
# display the Polar plot
plt.show()

# %% [markdown]
# Modify sin wave

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
    
# creating an array containing the
# radian values
x = np.arange(0, (2 * np.pi), 0.01)
y1 = np.sin(x*12)
y2 = np.sin(x*6)
y3 = np.sin(x*4)
# plotting the circle
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

# display the Polar plot
plt.show()

# %% [markdown]
# Plot cos wave

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
    
# creating an array containing the
# radian values
x = np.arange(0, (2 * np.pi), 0.01)
y = np.cos(x)  

# plotting the circle
plt.plot(x, y)
  
# display the Polar plot
plt.show()

# %% [markdown]
# Plot sin(x) + cos(x)

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
    
# creating an array containing the
# radian values
x = np.arange(0, (2 * np.pi), 0.01)
y = np.cos(x)  + np.sin(x)

# plotting the circle
plt.plot(x, y)
  
# display the Polar plot
plt.show()

# %% [markdown]
# Plot heart shape in polar curve

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')

# Creating equally spaced 100 data in range 0 to 2*pi
x = np.linspace(0, 2 * np.pi, 100)

y = 2 - 2*np.sin(x) + np.sin(x)*(np.abs(np.cos(x)))/(np.sin(x) + 1.4)

# Plotting
plt.plot(x, y)
plt.title('Heart Shape')
plt.show()

# %% [markdown]
# Plot sin signal

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
    
# creating an array containing the
# radian values
x = np.arange(0, (2 * np.pi), 0.01)
y = 0.1 * np.sin(2 * np.pi * 50 * x) 

# plotting the circle
plt.plot(x, y)
  
# display the Polar plot
plt.show()
